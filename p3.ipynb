# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users/rahul/Documents/train_LZdllcl.csv")

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
df.tail()
# Out:
#        employee_id         department     region         education gender  \
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 54803            sourcing                1   48                   3.0
# 54804               other                1   37                   2.0
# 54805               other                1   27                   5.0
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# ...

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
df.columns.tolist()
# Out:
# ['employee_id',
#  'department',
#  'region',
#  'education',
#  'gender',
#  'recruitment_channel',
#  'no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'KPIs_met >80%',
#  'awards_won?',
#  'avg_training_score',
#  'is_promoted']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
dept_count = df['department'].value_counts()

# %%
dept_count
# Out:
# department
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: count, dtype: int64

# %%
dpt_count = dept_count.reset_index()

# %%
dpt_count.columns=['Department','Dpt_count']

# %%
dpt_count
# Out:
#           Department  Dpt_count
# 0  Sales & Marketing      16840
# 1         Operations      11348
# 2         Technology       7138
# 3        Procurement       7138
# 4          Analytics       5352
# 5            Finance       2536
# 6                 HR       2418
# 7              Legal       1039
# 8                R&D        999

# %%
dept_count = df['department'].value_counts()

# %%
department_df = dept_count.reset_index()

# %%
department_df
# Out:
#           department  count
# 0  Sales & Marketing  16840
# 1         Operations  11348
# 2         Technology   7138
# 3        Procurement   7138
# 4          Analytics   5352
# 5            Finance   2536
# 6                 HR   2418
# 7              Legal   1039
# 8                R&D    999

# %%
department_df.columns=['Department','Dept_count']

# %%
department_df
# Out:
#           Department  Dept_count
# 0  Sales & Marketing       16840
# 1         Operations       11348
# 2         Technology        7138
# 3        Procurement        7138
# 4          Analytics        5352
# 5            Finance        2536
# 6                 HR        2418
# 7              Legal        1039
# 8                R&D         999

# %%
gender_d = df['gender'].value_counts()

# %%
gender_d.reset_index()
# Out:
#   gender  count
# 0      m  38496
# 1      f  16312

# %%
gender_d.columns=['g_data','g_count']

# %%
gender_d
# Out:
# gender
# m    38496
# f    16312
# Name: count, dtype: int64

# %%
g_ratio = df.groupby(['department','gender']).size().unstack(fill_value=0)

# %%
g_ratio
# Out:
# gender                f      m
# department
# Analytics           513   4839
# Finance             681   1855
# HR                 1006   1412
# Legal               149    890
# Operations         4677   6671
# Procurement        3287   3851
# R&D                  57    942
# Sales & Marketing  3154  13686
# Technology         2788   4350

# %%
age_summary = df['age'].describe()

# %%
age_summary
# Out:
# count    54808.000000
# mean        34.803915
# std          7.660169
# min         20.000000
# 25%         29.000000
# 50%         33.000000
# 75%         39.000000
# max         60.000000
# Name: age, dtype: float64

# %%
g_data = df['gender'].value_counts()

# %%
g_data
# Out:
# gender
# m    38496
# f    16312
# Name: count, dtype: int64

# %%
g_ratio = g_data.reset_index()

# %%
g_ratio
# Out:
#   gender  count
# 0      m  38496
# 1      f  16312

# %%
#g_ratio = df.groupby(['department','gender']).size().unstack(fill_value=0)
gender_ratio = df.groupby(['department', 'gender']).size().unstack()

# %%
gender_ratio
# Out:
# gender                f      m
# department
# Analytics           513   4839
# Finance             681   1855
# HR                 1006   1412
# Legal               149    890
# Operations         4677   6671
# Procurement        3287   3851
# R&D                  57    942
# Sales & Marketing  3154  13686
# Technology         2788   4350

# %%
gender_ratio.columns=['Male Count', 'Female Count']

# %%
gender_ratio
# Out:
#                    Male Count  Female Count
# department
# Analytics                 513          4839
# Finance                   681          1855
# HR                       1006          1412
# Legal                     149           890
# Operations               4677          6671
# Procurement              3287          3851
# R&D                        57           942
# Sales & Marketing        3154         13686
# Technology               2788          4350

# %%
g_rat = g_ratio.reset_index()

# %%
g_r
# Out:
# gender         department     f      m
# 0               Analytics   513   4839
# 1                 Finance   681   1855
# 2                      HR  1006   1412
# 3                   Legal   149    890
# 4              Operations  4677   6671
# 5             Procurement  3287   3851
# 6                     R&D    57    942
# 7       Sales & Marketing  3154  13686
# 8              Technology  2788   4350

# %%
gender_ratio.columns = ['Female Count', 'Male Count']

# %%
gender_ratio
# Out:
#                    Female Count  Male Count
# department
# Analytics                   513        4839
# Finance                     681        1855
# HR                         1006        1412
# Legal                       149         890
# Operations                 4677        6671
# Procurement                3287        3851
# R&D                          57         942
# Sales & Marketing          3154       13686
# Technology                 2788        4350

# %%
gender_ratio['Female to Male Count Ration'] = df['Female Co']

# %%
age_summary = df['age'].describe()

# %%
age_summary
# Out:
# count    54808.000000
# mean        34.803915
# std          7.660169
# min         20.000000
# 25%         29.000000
# 50%         33.000000
# 75%         39.000000
# max         60.000000
# Name: age, dtype: float64

# %%
g_ratio['Female to Male Ratio'] = g_ratio['Female Count']/g_ratio['Male Count']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 g_ratio['Female to Male Ratio'] = g_ratio['Female Count']/g_ratio['Male Count']
#
# NameError: name 'g_ratio' is not defined

# %%
g_ratio['Female to Male Count Ratio'] = g_ratio['Male Count'] / g_ratio['Female Count]

# %%
edu = df['education'].value_counts()

# %%
edu
# Out:
# education
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: count, dtype: int64

# %%
edu_index = edu.reset_index()

# %%
edu_index
# Out:
#           education  count
# 0        Bachelor's  36669
# 1  Master's & above  14925
# 2   Below Secondary    805

# %%
edu_index.columns=['Edu','Edu_count']

# %%
edu_index
# Out:
#                 Edu  Edu_count
# 0        Bachelor's      36669
# 1  Master's & above      14925
# 2   Below Secondary        805

# %%
recruit = df['recruitment_channel'].value_counts()

# %%
recruit
# Out:
# recruitment_channel
# other       30446
# sourcing    23220
# referred     1142
# Name: count, dtype: int64

# %%
sns.boxplot(x=df['previous_year_rating'])
plt.show()

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df = df.drop('Female to Male Count Ratio', axis=1)

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64
