# %%
import pandas as pd

# %%
my_dict = {"Name":['Gaurav','Rohit','Raghav','A','B'], "Age":[21,22,23,24,25], "Address":['Delhi','Haryana','USA','MP','UP'],"Phone No":[123,345,678,910,234]}

# %%
my_dict
# Out:
# {'Name': ['Gaurav', 'Rohit', 'Raghav', 'A', 'B'],
#  'Age': [21, 22, 23, 24, 25],
#  'Address': ['Delhi', 'Haryana', 'USA', 'MP', 'UP'],
#  'Phone No': [123, 345, 678, 910, 234]}

# %%
id = [1,2,3,4,5]
id1=pd.Series(id)

# %%
#id = ['a','b','c','d','e']
#id1=pd.Series(id)

# %%
df=pd.DataFrame(my_dict)

# %%
df=pd.DataFrame(my_dict,index=['a','b','c','d','e'])
df=pd.DataFrame(my_dict,index=df['Name'])
df=pd.DataFrame(my_dict,index=id1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 df=pd.DataFrame(my_dict,index=['a','b','c','d','e'])
#       2 df=pd.DataFrame(my_dict,index=df['Name'])
# ----> 3 df=pd.DataFrame(my_dict,index=id1)
#
# NameError: name 'id1' is not defined

# %%
df
# Out:
#      Name  Age  Address  Phone No
# 0  Gaurav   21    Delhi       123
# 1   Rohit   22  Haryana       345
# 2  Raghav   23      USA       678
# 3       A   24       MP       910
# 4       B   25       UP       234

# %%
df['birth_year']=2025-df['Age']

# %%
df
# Out:
#      Name   Age  Address  Phone No  birth_year
# a  Gaurav  21.0    Delhi     123.0      2004.0
# b   Rohit   NaN  Haryana     345.0         NaN
# c  Raghav  23.0     None     678.0      2002.0
# d       A  24.0       MP     910.0      2001.0
# e    None   NaN       UP       NaN         NaN

# %%
dfs=df['Age'].fillna(0)

# %%
a=int(df['Age'].mean())

# %%
#df['Age']=df['Age'].fillna(df['Age'].mean())
df['Age']=df['Age'].fillna(a)

# %%
df
# Out:
#      Name        Age  Address  Phone No  birth_year category  salary  \
# a  Gaurav  21.000000    Delhi     123.0      2004.0        A   15000
# b   Rohit  22.666667  Haryana     345.0         NaN        B   30000
# c  Raghav  23.000000     None     678.0      2002.0        A   30000
# d       A  24.000000       MP     910.0      2001.0        A   30000
# e    None  22.666667       UP       NaN         NaN        B   30000
#
#               standard  title
# a  uppper middel class   genz
# b  uppper middel class  bkwss
# c  uppper middel class  bkwss
# d  uppper middel class  bkwss
# e  uppper middel class  bkwss

# %%
dfs
# Out:
# a    21.0
# b     0.0
# c    23.0
# d    24.0
# e     0.0
# Name: Age, dtype: float64

# %%
#loc
#iloc
df.loc[[2,4],['Name','Address']]
# Out:
#     Name  Address
# 2  Rohit  Haryana
# 4      A       MP

# %%
df.loc[['b','e'],['Name','Address']]
# Out:
#     Name  Address
# b  Rohit  Haryana
# e      B       UP

# %%
df.iloc[2,2]

# %%
#iloc#
df.iloc[2,2]
df.iloc[[2,4],[2,3]]
# Out:
#   Address  Phone No
# 3    None     678.0
# 5      UP       NaN

# %%
df.loc[df['Age']>22]
# Out:
#      Name  Age Address  Phone No
# c  Raghav   23     USA       678
# d       A   24      MP       910
# e       B   25      UP       234

# %%
df.loc[df['Name']=='A']
# Out:
#   Name  Age Address  Phone No
# d    A   24      MP       910

# %%
df.loc[df['Name']!='A']
# Out:
#      Name  Age  Address  Phone No
# a  Gaurav   21    Delhi       123
# b   Rohit   22  Haryana       345
# c  Raghav   23      USA       678
# e       B   25       UP       234

# %%
df.loc[df['Name']!='Rohit']
# Out:
#      Name  Age Address  Phone No
# a  Gaurav   21   Delhi       123
# c  Raghav   23     USA       678
# d       A   24      MP       910
# e       B   25      UP       234

# %%
df['Address'].unique()
# Out:
# array(['Delhi', 'Haryana', 'USA', 'MP', 'UP'], dtype=object)

# %%
df.loc[df['Name'].str.startswith('G')]
#df.loc[df['Name'].str.endswith('A')]
# Out:
#      Name  Age Address  Phone No
# 0  Gaurav   21   Delhi       123

# %%
df.loc[df['Name'].str.endswith('v') & df['Name'].str.startswith('R')]
# Out:
#      Name  Age Address  Phone No
# 2  Raghav   23     USA       678

# %%
df.to_csv('python batch.csv',index=False,columns=['Name','Age','Address'])

# %%
import pandas as pd

df=pd.read_csv("c://Users/rahul/Downloads/Breast_Cancer.csv")
#df.pd.read_excel()
#df.pd.read_json()

#df=pd.read_csv("c:\\Users\rahul\Downloads\Breast_Cancer.csv")

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
df.tail(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 559  925291         B        11.51         23.93           74.52      403.5
# 560  925292         B        14.05         27.15           91.38      600.4
# 561  925311         B        11.20         29.37           70.67      386.0
# 562  925622         M        15.22         30.62          103.40      716.9
# 563  926125         M        20.92         25.09          143.00     1347.0
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.head(10)
df.head(61)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
df['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.loc[df['diagnosis']=='B']
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 19    8510426         B       13.540         14.36           87.46      566.3
# 20    8510653         B       13.080         15.71           85.63      520.0
# 21    8510824         B        9.504         12.44           60.34      273.9
# 37     854941         B       13.030         18.42           82.61      523.8
# 46   85713702         B        8.196         16.84           51.71      201.9
# ..        ...       ...          ...           ...             ...        ...
# 558    925277         B       14.590         22.68           96.39      657.1
# 559    925291         B       11.510         23.93           74.52      403.5
# 560    925292         B       14.050         27.15           91.38      600.4
# 561    925311         B       11.200         29.37           70.67      386.0
# 568     92751         B        7.760         24.54           47.92      181.0
#
# ...

# %%
#df.isnull()
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
#df.notnull()
df.notnull().sum()
# Out:
# id                         569
# diagnosis                  569
# radius_mean                569
# texture_mean               569
# perimeter_mean             569
# area_mean                  569
# smoothness_mean            569
# compactness_mean           569
# concavity_mean             569
# concave points_mean        569
# symmetry_mean              569
# fractal_dimension_mean     569
# radius_se                  569
# texture_se                 569
# perimeter_se               569
# area_se                    569
# smoothness_se              569
# compactness_se             569
# concavity_se               569
# concave points_se          569
# symmetry_se                569
# fractal_dimension_se       569
# radius_worst               569
# texture_worst              569
# perimeter_worst            569
# area_worst                 569
# smoothness_worst           569
# compactness_worst          569
# concavity_worst            569
# concave points_worst       569
# ...

# %%
import pandas as ps

# %%
my_dict = {"Name":['Gaurav','Rohit','Raghav','A',None], "Age":[21,None,23,24,None], "Address":['Delhi','Haryana',None,'MP','UP'],"Phone No":[123,345,678,910,None]}

# %%
id = ['a','b','c','d','e']
id1=pd.Series(id)

# %%
df=ps.DataFrame(my_dict,index=id1)

# %%
df
# Out:
#      Name   Age  Address  Phone No
# a  Gaurav  21.0    Delhi     123.0
# b   Rohit   NaN  Haryana     345.0
# c  Raghav  23.0     None     678.0
# d       A  24.0       MP     910.0
# e    None   NaN       UP       NaN

# %%
df.dropna(axis=0)
# Out:
#      Name   Age Address  Phone No
# a  Gaurav  21.0   Delhi       123
# d       A  24.0      MP       910

# %%
df.dropna(axis=1)
# Out:
#      Name  Phone No
# a  Gaurav       123
# b   Rohit       345
# c  Raghav       678
# d       A       910
# e       B       234

# %%
#thresh is number of not null value allowed in the data if any single value fail to concept of thresh than it will be remove 
df.dropna(axis=1,thresh=4)
# Out:
#      Name  Address  Phone No
# a  Gaurav    Delhi       123
# b   Rohit  Haryana       345
# c  Raghav     None       678
# d       A       MP       910
# e       B       UP       234

# %%
#how or thresh
df.dropna(axis=0,how='any')
# Out:
#      Name   Age Address  Phone No
# a  Gaurav  21.0   Delhi       123
# d       A  24.0      MP       910

# %%
#how or thresh
dffilter=df.dropna(axis=0,how='all',inplace)
# Out:
#      Name  Age  Address  Phone No
# 0  Gaurav   21    Delhi       123
# 1   Rohit   22  Haryana       345
# 2  Raghav   23      USA       678
# 3       A   24       MP       910
# 4       B   25       UP       234

# %%
df.dropna(axis=0,how='all',inplace=True)

# %%
df
# Out:
#      Name   Age  Address  Phone No
# a  Gaurav  21.0    Delhi     123.0
# b   Rohit   NaN  Haryana     345.0
# c  Raghav  23.0     None     678.0
# d       A  24.0       MP     910.0
# e    None   NaN       UP       NaN

# %%
df2=df.groupby('diagnosis')

# %%
df['radius_mean'].mean()
# Out:
# 14.127291739894552

# %%
df2['radius_mean'].mean()
# Out:
# diagnosis
# B    12.146524
# M    17.462830
# Name: radius_mean, dtype: float64

# %%
df2['radius_mean'].median()
# Out:
# diagnosis
# B    12.200
# M    17.325
# Name: radius_mean, dtype: float64

# %%
import pandas as pd
irispdf = pd.read_csv("c://Users/rahul/Downloads/iris_csv.csv")

# %%
irispdf
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
irispdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sepallength  150 non-null    float64
#  1   sepalwidth   150 non-null    float64
#  2   petallength  150 non-null    float64
#  3   petalwidth   150 non-null    float64
#  4   class        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
irispdf['class'].unique()
irispdf['class'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
irispdf['class'].value_counts()
# Out:
# class
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
irispdf2=irispdf.groupby('class')

# %%
irispdf2['sepallength'].mean()
# Out:
# class
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: sepallength, dtype: float64

# %%
irispdf2.agg({'sepallength':['mean','min','max','median'],'petallength':['mean','min','max','median']})
# Out:
#                 sepallength                  petallength
#                        mean  min  max median        mean  min  max median
# class
# Iris-setosa           5.006  4.3  5.8    5.0       1.464  1.0  1.9   1.50
# Iris-versicolor       5.936  4.9  7.0    5.9       4.260  3.0  5.1   4.35
# Iris-virginica        6.588  4.9  7.9    6.5       5.552  4.5  6.9   5.55

# %%
df.pivot_table(values='radius_mean',index=['diagnosis'],aggfunc=['mean','min'])
# Out:
#                  mean         min
#           radius_mean radius_mean
# diagnosis
# B           12.146524       6.981
# M           17.462830      10.950

# %%
#dataset formation 
classes = {'name': ['a','b','c','d',None,'f'],'section':['A',None,'A','B',None,'A'],'sub':['maths','english','maths','maths','english','maths'],'marks':[80,90,78,89,77,67]}

# %%
classes
# Out:
# {'name': ['a', 'b', 'c', 'd', None, 'f'],
#  'section': ['A', None, 'A', 'B', None, 'A'],
#  'sub': ['maths', 'english', 'maths', 'maths', 'english', 'maths'],
#  'marks': [80, 90, 78, 89, 77, 67]}

# %%
import pandas as pd
df1=pd.DataFrame(classes)
df1
# Out:
#    name section      sub  marks
# 0     a       A    maths     80
# 1     b    None  english     90
# 2     c       A    maths     78
# 3     d       B    maths     89
# 4  None    None  english     77
# 5     f       A    maths     67

# %%
df1.pivot_table(values='marks',index=['sub','section'],aggfunc=['mean','sum'])
# Out:
#                mean   sum
#               marks marks
# sub   section
# maths A        75.0   225
#       B        89.0    89

# %%
df
# Out:
#      Name        Age  Address  Phone No  birth_year
# a  Gaurav  21.000000    Delhi     123.0      2004.0
# b   Rohit  22.666667  Haryana     345.0         NaN
# c  Raghav  23.000000     None     678.0      2002.0
# d       A  24.000000       MP     910.0      2001.0
# e    None  22.666667       UP       NaN         NaN

# %%
b=['A','B','A','A','B']
df['category']=b

# %%
df
# Out:
#      Name        Age  Address  Phone No  birth_year category
# a  Gaurav  21.000000    Delhi     123.0      2004.0        A
# b   Rohit  22.666667  Haryana     345.0         NaN        B
# c  Raghav  23.000000     None     678.0      2002.0        A
# d       A  24.000000       MP     910.0      2001.0        A
# e    None  22.666667       UP       NaN         NaN        B

# %%
c = []

for i in df['Age']:
    if i>22:
        c.append(20000)
    else:
        c.append(10000)

df['salary']=c
df
# Out:
#      Name        Age  Address  Phone No  birth_year category  salary
# a  Gaurav  21.000000    Delhi     123.0      2004.0        A   10000
# b   Rohit  22.666667  Haryana     345.0         NaN        B   20000
# c  Raghav  23.000000     None     678.0      2002.0        A   20000
# d       A  24.000000       MP     910.0      2001.0        A   20000
# e    None  22.666667       UP       NaN         NaN        B   20000

# %%
df['salary']=df['Age'].apply(lambda x:30000 if x>22 else 15000)

#lambada is a anomanous function for x is denoting every age of value if x>22

# %%
df
# Out:
#      Name        Age  Address  Phone No  birth_year category  salary
# a  Gaurav  21.000000    Delhi     123.0      2004.0        A   15000
# b   Rohit  22.666667  Haryana     345.0         NaN        B   30000
# c  Raghav  23.000000     None     678.0      2002.0        A   30000
# d       A  24.000000       MP     910.0      2001.0        A   30000
# e    None  22.666667       UP       NaN         NaN        B   30000

# %%
df['standard']=df['salary'].apply(lambda t: 'uppper middel class' if t>1600 else 'lower middle class')

# %%
df
# Out:
#      Name        Age  Address  Phone No  birth_year category  salary  \
# a  Gaurav  21.000000    Delhi     123.0      2004.0        A   15000
# b   Rohit  22.666667  Haryana     345.0         NaN        B   30000
# c  Raghav  23.000000     None     678.0      2002.0        A   30000
# d       A  24.000000       MP     910.0      2001.0        A   30000
# e    None  22.666667       UP       NaN         NaN        B   30000
#
#               standard
# a  uppper middel class
# b  uppper middel class
# c  uppper middel class
# d  uppper middel class
# e  uppper middel class

# %%
df['title']=df['Address'].apply(lambda y:'genz' if x=='Delhi' elif 'Desi' x=='Haryana' else 'bhaad mein jao')
# Out:
#   Cell In[224], line 1
#     df['title']=df['Address'].apply(lambda y:'genz' if x=='Delhi' elif 'Desi' x=='Haryana' else 'bhaad mein jao')
#                                              ^
# SyntaxError: expected 'else' after 'if' expression

# %%
df['title']=df['Address'].apply(lambda x:'genz' if x=='Delhi' else('desi' if x=='haryana' else('good boy' if x=='up' else 'bkwss')))

df
# Out:
#      Name        Age  Address  Phone No  birth_year category  salary  \
# a  Gaurav  21.000000    Delhi     123.0      2004.0        A   15000
# b   Rohit  22.666667  Haryana     345.0         NaN        B   30000
# c  Raghav  23.000000     None     678.0      2002.0        A   30000
# d       A  24.000000       MP     910.0      2001.0        A   30000
# e    None  22.666667       UP       NaN         NaN        B   30000
#
#               standard  title
# a  uppper middel class   genz
# b  uppper middel class  bkwss
# c  uppper middel class  bkwss
# d  uppper middel class  bkwss
# e  uppper middel class  bkwss

# %%
import numpy as np
import matplotlib.pyplot as plt
xpoint = np.array([0,6,7,9,1])
ypoint = np.array([0,25,45,55,67])

plt.plot(xpoint,ypoint)

# %%
x = np.array([1,3,5,7,9])
y=np.array([22,33,44,55,66])
plt.plot(xpoint,ypoint)

# %%
x = np.array([1,3,5,7,9])
y=np.array([22,33,44,55,66])
plt.plot(xpoint,ypoint)
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title("graph 1")
plt.show()
plt.plot(x,y)
plt.xlabel('x axis2')
plt.ylabel('y axis2')
plt.title("graph 2")
plt.show()

# %%
import pandas as pd
irispdf = pd.read_csv("c://Users/rahul/Downloads/iris_csv.csv")

# %%
irispdf.Data
# Out:
#      sepallength  sepalwidth  petallength  petalwidth           class
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]
