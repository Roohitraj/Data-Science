# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C://Users/rahul/Documents/train_LZdllcl.csv")

# %%
dfq = pd.read_csv("C://Users/rahul/Documents/train_LZdllcl.csv")

# %%
dfq
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
df.columns.tolist()
# Out:
# ['employee_id',
#  'department',
#  'region',
#  'education',
#  'gender',
#  'recruitment_channel',
#  'no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'KPIs_met >80%',
#  'awards_won?',
#  'avg_training_score',
#  'is_promoted']

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
df.tail()
# Out:
#        employee_id         department     region         education gender  \
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 54803            sourcing                1   48                   3.0
# 54804               other                1   37                   2.0
# 54805               other                1   27                   5.0
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# ...

# %%
df['recruitment_channel'].unique()
# Out:
# array(['sourcing', 'other', 'referred'], dtype=object)

# %%
df['recruitment_channel'].value_counts()
# Out:
# recruitment_channel
# other       30446
# sourcing    23220
# referred     1142
# Name: count, dtype: int64

# %%
df.iloc[[1,2],[2,5]] # iloc through only indexing wise data filter
# Out:
#       region recruitment_channel
# 1  region_22               other
# 2  region_19            sourcing

# %%
df.loc[[1,2],['department','region']] #column name wise or index wise data filter through loc
# Out:
#           department     region
# 1         Operations  region_22
# 2  Sales & Marketing  region_19

# %%
df.dropna(axis=0,how='any')
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54802         6915  Sales & Marketing  region_14        Bachelor's      m
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.to_numpy()
# Out:
# array([[65438, 'Sales & Marketing', 'region_7', ..., 0, 49, 0],
#        [65141, 'Operations', 'region_22', ..., 0, 60, 0],
#        [7513, 'Sales & Marketing', 'region_19', ..., 0, 50, 0],
#        ...,
#        [13918, 'Analytics', 'region_1', ..., 0, 79, 0],
#        [13614, 'Sales & Marketing', 'region_9', ..., 0, 45, 0],
#        [51526, 'HR', 'region_22', ..., 0, 49, 0]], dtype=object)

# %%
df.T
# Out:
#                                   0           1                  2      \
# employee_id                       65438       65141               7513
# department            Sales & Marketing  Operations  Sales & Marketing
# region                         region_7   region_22          region_19
# education              Master's & above  Bachelor's         Bachelor's
# gender                                f           m                  m
# recruitment_channel            sourcing       other           sourcing
# no_of_trainings                       1           1                  1
# age                                  35          30                 34
# previous_year_rating                5.0         5.0                3.0
# length_of_service                     8           4                  7
# KPIs_met >80%                         1           0                  0
# awards_won?                           0           0                  0
# ...

# %%
dept = df['department'].value_counts()

# %%
dept
# Out:
# department
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: count, dtype: int64

# %%
dept_count = dept.reset_index()

# %%
dept_count.columns = ['Department','Dept_count']

# %%
dept_count
# Out:
#           Department  Dept_count
# 0  Sales & Marketing       16840
# 1         Operations       11348
# 2         Technology        7138
# 3        Procurement        7138
# 4          Analytics        5352
# 5            Finance        2536
# 6                 HR        2418
# 7              Legal        1039
# 8                R&D         999

# %%
dept = df['department'].value_counts()

# %%
dept
# Out:
# department
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: count, dtype: int64

# %%
dept_count = dept.reset_index()

# %%
dept_count.columns=['Dept','D_count']

# %%
dept_count
# Out:
#                 Dept  D_count
# 0  Sales & Marketing    16840
# 1         Operations    11348
# 2         Technology     7138
# 3        Procurement     7138
# 4          Analytics     5352
# 5            Finance     2536
# 6                 HR     2418
# 7              Legal     1039
# 8                R&D      999

# %%
g_count = df['gender'].value_counts()

# %%
g_count
# Out:
# gender
# m    38496
# f    16312
# Name: count, dtype: int64

# %%
g_data = dfs.groupby(['department','gender']).size().unstack(fill_values=0)

# %%
g_data
# Out:
# department         gender
# Analytics          f           513
#                    m          4839
# Finance            f           681
#                    m          1855
# HR                 f          1006
#                    m          1412
# Legal              f           149
#                    m           890
# Operations         f          4677
#                    m          6671
# Procurement        f          3287
#                    m          3851
# R&D                f            57
#                    m           942
# Sales & Marketing  f          3154
#                    m         13686
# Technology         f          2788
#                    m          4350
# dtype: int64

# %%
g_data = df.groupby(['department','gender']).size().unstack(fill_value=0)

# %%
g_data
# Out:
# gender                f      m
# department
# Analytics           513   4839
# Finance             681   1855
# HR                 1006   1412
# Legal               149    890
# Operations         4677   6671
# Procurement        3287   3851
# R&D                  57    942
# Sales & Marketing  3154  13686
# Technology         2788   4350

# %%
gender_ratio = df.groupby(['department','gender']).size()

# %%
gender_ratio
# Out:
# department         gender
# Analytics          f           513
#                    m          4839
# Finance            f           681
#                    m          1855
# HR                 f          1006
#                    m          1412
# Legal              f           149
#                    m           890
# Operations         f          4677
#                    m          6671
# Procurement        f          3287
#                    m          3851
# R&D                f            57
#                    m           942
# Sales & Marketing  f          3154
#                    m         13686
# Technology         f          2788
#                    m          4350
# dtype: int64

# %%
gender_ratio['Total'] = g_count.sum()

# %%
gender_ratio.columns = ['Female Count', 'Male Count']
gender_ratio.columns = ['Female COunt', 'Male Count']

# %%
gender_ratio
# Out:
# department         gender
# Analytics          f           513
#                    m          4839
# Finance            f           681
#                    m          1855
# HR                 f          1006
#                    m          1412
# Legal              f           149
#                    m           890
# Operations         f          4677
#                    m          6671
# Procurement        f          3287
#                    m          3851
# R&D                f            57
#                    m           942
# Sales & Marketing  f          3154
#                    m         13686
# Technology         f          2788
#                    m          4350
# Total                        54808
# dtype: int64

# %%
age_summary = df['age'].describe()

# %%
age_summary
# Out:
# count    54808.000000
# mean        34.803915
# std          7.660169
# min         20.000000
# 25%         29.000000
# 50%         33.000000
# 75%         39.000000
# max         60.000000
# Name: age, dtype: float64

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
dept_average = df['department'].describe()

# %%
dept_average
# Out:
# count                 54808
# unique                    9
# top       Sales & Marketing
# freq                  16840
# Name: department, dtype: object

# %%
region_avg = df['region'].describe()

# %%
region_avg
# Out:
# count        54808
# unique          34
# top       region_2
# freq         12343
# Name: region, dtype: object

# %%
education_avg = df['education'].describe()

# %%
education_avg
# Out:
# count          52399
# unique             3
# top       Bachelor's
# freq           36669
# Name: education, dtype: object

# %%
gender_avg = df['gender'].describe()

# %%
gender_avg
# Out:
# count     54808
# unique        2
# top           m
# freq      38496
# Name: gender, dtype: object

# %%
recruitment_channel_avg = df['recruitment_channel'].describe()

# %%
recruitment_channel_avg
# Out:
# count     54808
# unique        3
# top       other
# freq      30446
# Name: recruitment_channel, dtype: object

# %%
no_of_trainings_avg = df['no_of_trainings'].describe()

# %%
no_of_trainings_avg
# Out:
# count    54808.000000
# mean         1.253011
# std          0.609264
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max         10.000000
# Name: no_of_trainings, dtype: float64

# %%
previous_year_rating_avg = df['previous_year_rating'].describe()

# %%
previous_year_rating_avg
# Out:
# count    50684.000000
# mean         3.329256
# std          1.259993
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: previous_year_rating, dtype: float64

# %%
length_of_service_avg = df['length_of_service'].describe()

# %%
length_of_service_avg
# Out:
# count    54808.000000
# mean         5.865512
# std          4.265094
# min          1.000000
# 25%          3.000000
# 50%          5.000000
# 75%          7.000000
# max         37.000000
# Name: length_of_service, dtype: float64

# %%
KPIs_met_avg = df['KPIs_met >80%'].describe()

# %%
KPIs_met_avg
# Out:
# count    54808.000000
# mean         0.351974
# std          0.477590
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: KPIs_met >80%, dtype: float64

# %%
awards_won_avg = df['awards_won?'].describe()

# %%
awards_won_avg
# Out:
# count    54808.000000
# mean         0.023172
# std          0.150450
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: awards_won?, dtype: float64

# %%
avg_training_score_avg = df['avg_training_score'].describe()

# %%
avg_training_score_avg
# Out:
# count    54808.000000
# mean        63.386750
# std         13.371559
# min         39.000000
# 25%         51.000000
# 50%         60.000000
# 75%         76.000000
# max         99.000000
# Name: avg_training_score, dtype: float64

# %%
is_promoted_avg = df['is_promoted'].describe()

# %%
is_promoted_avg
# Out:
# count    54808.000000
# mean         0.085170
# std          0.279137
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: is_promoted, dtype: float64

# %%
sns.boxplot(x=df['department'])
plt.show()

# %%
sns.boxplot(x=df['region'])
plt.show()

# %%
sns.boxplot(df['education'])
plt.show()

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df.isnull().sum()/len(df)*100
# Out:
# employee_id             0.000000
# department              0.000000
# region                  0.000000
# education               4.395344
# gender                  0.000000
# recruitment_channel     0.000000
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    7.524449
# length_of_service       0.000000
# KPIs_met >80%           0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64
