# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C://Users/rahul/Documents/train_LZdllcl.csv")

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['employee_id',
#  'department',
#  'region',
#  'education',
#  'gender',
#  'recruitment_channel',
#  'no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'KPIs_met >80%',
#  'awards_won?',
#  'avg_training_score',
#  'is_promoted']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
dep_count = df['department'].value_counts()

# %%
dep_count
# Out:
# department
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: count, dtype: int64

# %%
total_depart = dep_count.reset_index()

# %%
total_depart
# Out:
#           department  count
# 0  Sales & Marketing  16840
# 1         Operations  11348
# 2         Technology   7138
# 3        Procurement   7138
# 4          Analytics   5352
# 5            Finance   2536
# 6                 HR   2418
# 7              Legal   1039
# 8                R&D    999

# %%
dept_count = df['department'].value_counts()

# %%
dept_count
# Out:
# department
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: count, dtype: int64

# %%
depart_data = dept_count.reset_index()

# %%
depart_data
# Out:
#           department  count
# 0  Sales & Marketing  16840
# 1         Operations  11348
# 2         Technology   7138
# 3        Procurement   7138
# 4          Analytics   5352
# 5            Finance   2536
# 6                 HR   2418
# 7              Legal   1039
# 8                R&D    999

# %%
depart_data.columns=['department','emp_count']

# %%
depart_data
# Out:
#           department  emp_count
# 0  Sales & Marketing      16840
# 1         Operations      11348
# 2         Technology       7138
# 3        Procurement       7138
# 4          Analytics       5352
# 5            Finance       2536
# 6                 HR       2418
# 7              Legal       1039
# 8                R&D        999

# %%
gender_count = df['gender'].value_counts()

# %%
gender_count
# Out:
# gender
# m    38496
# f    16312
# Name: count, dtype: int64

# %%
data_gender = gender_count.reset_index()

# %%
data_gender
# Out:
#   gender  count
# 0      m  38496
# 1      f  16312

# %%
data_gender.columns=['gender_data','gen_count']

# %%
data_gender
# Out:
#   gender_data  gen_count
# 0           m      38496
# 1           f      16312

# %%
data_gender = df.groupby(['department','gender']).size().unstack(fill_value=0)

# %%
data_gender
# Out:
# gender                f      m
# department
# Analytics           513   4839
# Finance             681   1855
# HR                 1006   1412
# Legal               149    890
# Operations         4677   6671
# Procurement        3287   3851
# R&D                  57    942
# Sales & Marketing  3154  13686
# Technology         2788   4350

# %%
data_gender = df.groupby(['department','gender']).size().unstack(fill_value=0)

# %%
data_gender
# Out:
# gender                f      m
# department
# Analytics           513   4839
# Finance             681   1855
# HR                 1006   1412
# Legal               149    890
# Operations         4677   6671
# Procurement        3287   3851
# R&D                  57    942
# Sales & Marketing  3154  13686
# Technology         2788   4350

# %%
data_gender = df.groupby(['department','gender']).size()

# %%
data_gender
# Out:
# department         gender
# Analytics          f           513
#                    m          4839
# Finance            f           681
#                    m          1855
# HR                 f          1006
#                    m          1412
# Legal              f           149
#                    m           890
# Operations         f          4677
#                    m          6671
# Procurement        f          3287
#                    m          3851
# R&D                f            57
#                    m           942
# Sales & Marketing  f          3154
#                    m         13686
# Technology         f          2788
#                    m          4350
# dtype: int64

# %%
data_gender = df.groupby(['department','gender']).size().unstack(fill_value=0)

# %%
data_gender
# Out:
# gender                f      m
# department
# Analytics           513   4839
# Finance             681   1855
# HR                 1006   1412
# Legal               149    890
# Operations         4677   6671
# Procurement        3287   3851
# R&D                  57    942
# Sales & Marketing  3154  13686
# Technology         2788   4350

# %%
age_summary = df['age'].describe()

# %%
age_summary
# Out:
# count    54808.000000
# mean        34.803915
# std          7.660169
# min         20.000000
# 25%         29.000000
# 50%         33.000000
# 75%         39.000000
# max         60.000000
# Name: age, dtype: float64

# %%
dept_summary = df['previous_year_rating'].describe()

# %%
dept_summary
# Out:
# count    50684.000000
# mean         3.329256
# std          1.259993
# min          1.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: previous_year_rating, dtype: float64

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
sns.boxplot(x=df['previous_year_rating'])
plt.show()
sns.boxplot(x=df['previous_year_rating'])
plt.show()

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# employee_id             0.000000
# department              0.000000
# region                  0.000000
# education               4.395344
# gender                  0.000000
# recruitment_channel     0.000000
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    7.524449
# length_of_service       0.000000
# KPIs_met >80%           0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64

# %%
df.isnull().sum()/len(df)*100
# Out:
# employee_id             0.000000
# department              0.000000
# region                  0.000000
# education               4.395344
# gender                  0.000000
# recruitment_channel     0.000000
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    7.524449
# length_of_service       0.000000
# KPIs_met >80%           0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64

# %%
fill_data = df['education'].fillna("Unknown")

# %%
fill_data
# Out:
# 0        Master's & above
# 1              Bachelor's
# 2              Bachelor's
# 3              Bachelor's
# 4              Bachelor's
#                ...
# 54803          Bachelor's
# 54804    Master's & above
# 54805          Bachelor's
# 54806             Unknown
# 54807          Bachelor's
# Name: education, Length: 54808, dtype: object

# %%
fill_data.isnull().sum()
# after data you can check the column values wheather data is fill or not
# Out:
# 0

# %%
filter_data = df['education'].mode()

# %%
filter_data
# Out:
# 0    Bachelor's
# Name: education, dtype: object

# %%
filter_data = df['education'].fillna(df['education'].mode()[0])

# %%
filter_data
# Out:
# 0        Master's & above
# 1              Bachelor's
# 2              Bachelor's
# 3              Bachelor's
# 4              Bachelor's
#                ...
# 54803          Bachelor's
# 54804    Master's & above
# 54805          Bachelor's
# 54806          Bachelor's
# 54807          Bachelor's
# Name: education, Length: 54808, dtype: object
