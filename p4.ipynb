# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/rahul/Documents/train_LZdllcl.csv")

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# ...

# %%
df.tail()
# Out:
#        employee_id         department     region         education gender  \
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 54803            sourcing                1   48                   3.0
# 54804               other                1   37                   2.0
# 54805               other                1   27                   5.0
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
dept = df['department'].value_counts()

# %%
dept
# Out:
# department
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: count, dtype: int64

# %%
dept_count = dept.reset_index()

# %%
dept_count
# Out:
#           department  count
# 0  Sales & Marketing  16840
# 1         Operations  11348
# 2         Technology   7138
# 3        Procurement   7138
# 4          Analytics   5352
# 5            Finance   2536
# 6                 HR   2418
# 7              Legal   1039
# 8                R&D    999

# %%
dept_count.columns=['Dept','Dept_count']

# %%
dept_count
# Out:
#                 Dept  Dept_count
# 0  Sales & Marketing       16840
# 1         Operations       11348
# 2         Technology        7138
# 3        Procurement        7138
# 4          Analytics        5352
# 5            Finance        2536
# 6                 HR        2418
# 7              Legal        1039
# 8                R&D         999

# %%
g_ratio = df['gender'].value_counts()

# %%
g_ratio
# Out:
# gender
# m    38496
# f    16312
# Name: count, dtype: int64

# %%
g_data = g_ratio.reset_index()

# %%
g_data.columns=['Gender','Gender_count']

# %%
g_data
# Out:
#   Gender  Gender_count
# 0      m         38496
# 1      f         16312

# %%
g_ratio = df.groupby(['department','gender']).size().unstack(fill_value=0)

# %%
g_ratio.columns=['Male Count','Female Count']

# %%
g_ratio
# Out:
#                    Male Count  Female Count
# department
# Analytics                 513          4839
# Finance                   681          1855
# HR                       1006          1412
# Legal                     149           890
# Operations               4677          6671
# Procurement              3287          3851
# R&D                        57           942
# Sales & Marketing        3154         13686
# Technology               2788          4350

# %%
g_ratio['Female to Male Ratio'] = g_ratio['Female Count']/ g_ratio['Male Count']

# %%
g_ratio
# Out:
#                    Male Count  Female Count  Female to Male Ratio
# department
# Analytics                 513          4839              9.432749
# Finance                   681          1855              2.723935
# HR                       1006          1412              1.403579
# Legal                     149           890              5.973154
# Operations               4677          6671              1.426342
# Procurement              3287          3851              1.171585
# R&D                        57           942             16.526316
# Sales & Marketing        3154         13686              4.339252
# Technology               2788          4350              1.560258

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=df, x='department' , y='gender', hue='gender',bins=10, kde=True, color='blue')
# Out:
# <Axes: xlabel='department', ylabel='gender'>

# %%
plt.figure(figsize=(8,4))
sns.barplot(x='department', y='Female to Male Ratio', data=g_ratio)
plt.xlabel('Department')
plt.ylabel('Female-to-Male Ratio')
plt.title('Female-to-Male Ratio by Department')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7, 8],
#  [Text(0, 0, 'Analytics'),
#   Text(1, 0, 'Finance'),
#   Text(2, 0, 'HR'),
#   Text(3, 0, 'Legal'),
#   Text(4, 0, 'Operations'),
#   Text(5, 0, 'Procurement'),
#   Text(6, 0, 'R&D'),
#   Text(7, 0, 'Sales & Marketing'),
#   Text(8, 0, 'Technology')])

# %%
plt.figure(figsize=(8, 5))

sns.histplot(df['age'], bins=10, kde=True, color='green')
# Labels and title
plt.xlabel('Age')
plt.ylabel('Number of Employees')
plt.title('Age Distribution of Employees')
# Create histogram
#Kernel Density Estimate (KDE) curve
# Out:
# Text(0.5, 1.0, 'Age Distribution of Employees')

# %%
age_summary = df['age'].describe()

# %%
age_summary.reset_index()
# Out:
#    index           age
# 0  count  54808.000000
# 1   mean     34.803915
# 2    std      7.660169
# 3    min     20.000000
# 4    25%     29.000000
# 5    50%     33.000000
# 6    75%     39.000000
# 7    max     60.000000

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
edu = df['education'].value_counts()

# %%
 edu.reset_index()
# Out:
#           education  count
# 0        Bachelor's  36669
# 1  Master's & above  14925
# 2   Below Secondary    805

# %%
rec_data = df['recruitment_channel'].value_counts()

# %%
rec = rec_data.reset_index()

# %%
rec.columns=['recruitement','recruitement_channel']

# %%
rec
# Out:
#   recruitement  recruitement_channel
# 0        other                 30446
# 1     sourcing                 23220
# 2     referred                  1142

# %%
sns.boxplot(x=df['previous_year_rating'])
plt.show()

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# employee_id             0.000000
# department              0.000000
# region                  0.000000
# education               4.395344
# gender                  0.000000
# recruitment_channel     0.000000
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    7.524449
# length_of_service       0.000000
# KPIs_met >80%           0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64

# %%
df.isnull().sum()/len(df)*100
# Out:
# employee_id             0.000000
# department              0.000000
# region                  0.000000
# education               4.395344
# gender                  0.000000
# recruitment_channel     0.000000
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    7.524449
# length_of_service       0.000000
# KPIs_met >80%           0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64

# %%
df.isnull().sum()/len(df)*100
# Out:
# employee_id             0.000000
# department              0.000000
# region                  0.000000
# education               4.395344
# gender                  0.000000
# recruitment_channel     0.000000
# no_of_trainings         0.000000
# age                     0.000000
# previous_year_rating    7.524449
# length_of_service       0.000000
# KPIs_met >80%           0.000000
# awards_won?             0.000000
# avg_training_score      0.000000
# is_promoted             0.000000
# dtype: float64

# %%
filled = df['education'].fillna('Unknown')

# %%
filled
# Out:
# 0        Master's & above
# 1              Bachelor's
# 2              Bachelor's
# 3              Bachelor's
# 4              Bachelor's
#                ...
# 54803          Bachelor's
# 54804    Master's & above
# 54805          Bachelor's
# 54806             Unknown
# 54807          Bachelor's
# Name: education, Length: 54808, dtype: object

# %%
filled.isnull().sum()
# Out:
# 0

# %%
filled = df['education'].mode()

# %%
filled
# Out:
# 0    Bachelor's
# Name: education, dtype: object

# %%
filled = df['education'].fillna(df['education'].mode()[0])

# %%
filled
# Out:
# 0        Master's & above
# 1              Bachelor's
# 2              Bachelor's
# 3              Bachelor's
# 4              Bachelor's
#                ...
# 54803          Bachelor's
# 54804    Master's & above
# 54805          Bachelor's
# 54806          Bachelor's
# 54807          Bachelor's
# Name: education, Length: 54808, dtype: object

# %%
filled = df['education'].fillna(df['education'].mode()[0])

# %%
filled
# Out:
# 0        Master's & above
# 1              Bachelor's
# 2              Bachelor's
# 3              Bachelor's
# 4              Bachelor's
#                ...
# 54803          Bachelor's
# 54804    Master's & above
# 54805          Bachelor's
# 54806          Bachelor's
# 54807          Bachelor's
# Name: education, Length: 54808, dtype: object

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
#6
avg_score = df.groupby("department")["avg_training_score"].mean()
avg_df = avg_score.reset_index()
avg_df.columns=['Department','Avg_training_score']

# %%
avg_df
# Out:
#           Department  Avg_training_score
# 0          Analytics           84.602952
# 1            Finance           60.222003
# 2                 HR           50.018197
# 3              Legal           59.868142
# 4         Operations           60.226648
# 5        Procurement           70.122443
# 6                R&D           84.596597
# 7  Sales & Marketing           50.261698
# 8         Technology           79.928692

# %%
df['age'].std()
# Out:
# 7.660169201585887

# %%
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
t = df.columns.tolist()

# %%
#7
corr = df['no_of_trainings'].corr(df['avg_training_score'])
print(f"correlation data : {corr:.2f}")
if corr > 0.7:
    print(f"Correlation :{corr:.2f}")
elif corr >0.3:
    print(f"correlation :{corr:.2f}")
elif corr > 0:
    print(f"correlation : {corr:.2f}")
elif corr < -0.7:
    print(f"correleation : {corr:.2f}")
elif corr <- 0.3:
    print(f"correleation : {corr:.2f}")
elif corr <-0:
    print(f"correleation : {corr:.2f}")
else:
    print(f"Correlation = {correlation:.2f} → No Correlation (Training count does not significantly impact performance) ❓")
# Out:
# correlation data : 0.04

# %%
#7
corr = df['no_of_trainings'].corr(df['avg_training_score'])
print(f"correlation data in : {corr:.2f}")
if corr > 0.7:
    print(f"Correlation :{corr:.2f}")
elif corr >0.3:
    print(f"correlation :{corr:.2f}")
elif corr > 0:
    print(f"correlation : {corr:.2f}")
elif corr < -0.7:
    print(f"correleation : {corr:.2f}")
elif corr <- 0.3:
    print(f"correleation : {corr:.2f}")
elif corr <-0:
    print(f"correleation : {corr:.2f}")
else:
    print(f"Correlation = {correlation:.2f} → No Correlation (Training count does not significantly impact performance) ❓")
# Out:
# correlation data in : 0.04
# correlation : 0.04

# %%
#8
highest = df['no_of_trainings'].corr(df['previous_year_rating'])
print(f"highest correlation:{highest:.2f}")
if highest >0.7:
    print(f"highest correlation : {highest:.2f}")
elif highest> 0.3:
    print(f"highest correlation : {highest:.2f}")
elif highest > 0:
    print(f"highest correlation : {highest:.2f}")
elif highest < -0.7:
    print(f"highest correlation : {highest:.2f}")
elif highest < -0.3:
    print(f"highest correlation : {highest:.2f}")
elif highest < -0:
    print(f"highest correlation : {highest:.2f}")
else:
    print(f"highest correlation : {highest:.2f}")
# Out:
# highest correlation:-0.06
# highest correlation : -0.06

# %%
#9 
kpi = df['no_of_trainings'].corr(df['KPIs_met >80%'])
print(f"Training correleation : {kpi:.2f}")
if kpi  > 0.7:
    print(f"Training correleation : {kpi:.2f}")
elif kpi > 0.3:
    print(f"Training correleation : {kpi:.2f}")
elif kpi > 0:
    print(f"Training correleation : {kpi:.2f}")
elif kpi < -0.7:
    print(f"Training correleation : {kpi:.2f}")
elif kpi < -0.3:
    print(f"Training correleation : {kpi:.2f}")
elif kpi < -0:
    print(f"Training correleation : {kpi:.2f}")
else:
    print(f"Training correleation : {kpi:.2f}")
# Out:
# Training correleation : -0.05
# Training correleation : -0.05

# %%
corr = df['avg_training_score'].corr(df['length_of_service'])
print(f"Correlation : {corr:.2f}")
if kpi >0.7:
    print(f"Correlation : {corr:.2f}")
elif kpi > 0.3:
    print(f"Correlation : {corr:.2f}")
elif kpi > 0:
    print(f"Correlation : {corr:.2f}")
elif kpi < - 0.7:
    print(f"Correlation : {corr:.2f}")
elif kpi < -0.3:
    print(f"Correlation : {corr:.2f}")
elif kpi < - 0:
    print(f"Correlation : {corr:.2f}")
else:
    print(f"Correlation : {corr:.2f}")
# Out:
# Correlation : -0.04
# Correlation : -0.04

# %%
t
# Out:
# ['employee_id',
#  'department',
#  'region',
#  'education',
#  'gender',
#  'recruitment_channel',
#  'no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'KPIs_met >80%',
#  'awards_won?',
#  'avg_training_score',
#  'is_promoted']

# %%
# interpetation for logic code to garph automatically co relation graph is justify
plt.figure(figsize=(8, 5))

# Create scatter plot
sns.scatterplot(data=df, x="length_of_service", y="avg_training_score", alpha=0.6, color="blue")

# Add trendline (optional)
sns.regplot(data=df, x="length_of_service", y="avg_training_score", scatter=False, color="red")

# Labels and title
plt.title("Impact of Length of Service on Training Scores")
plt.xlabel("Length of Service (Years)")
plt.ylabel("Average Training Score")

# Show plot
plt.show()

# %%
promoted = df['is_promoted'].mean()*100

# %%
promoted
# Out:
# 8.517004816815064

# %%
promoted = df['is_promoted'].mean()*100

# %%
promoted
# Out:
# 8.517004816815064

# %%
dept_highest = df.groupby('department')['is_promoted'].sum()
dept = dept_highest.reset_index()
dept.columns=['Department','Project Count']
data = dept.loc[dept['Project Count'].idxmax()]
data
# Out:
# Department       Sales & Marketing
# Project Count                 1213
# Name: 7, dtype: object

# %%
gender_ratio = df.groupby('gender')['is_promoted'].mean()*100

# %%
gender_ratio.reset_index()
# Out:
#   gender  is_promoted
# 0      f     8.993379
# 1      m     8.315150

# %%
previous = df.groupby('previous_year_rating')['is_promoted'].mean()*100

# %%
previous.reset_index()
# Out:
#    previous_year_rating  is_promoted
# 0                   1.0     1.414109
# 1                   2.0     4.284024
# 2                   3.0     7.277903
# 3                   4.0     7.937633
# 4                   5.0    16.361468

# %%
t
# Out:
# ['employee_id',
#  'department',
#  'region',
#  'education',
#  'gender',
#  'recruitment_channel',
#  'no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'KPIs_met >80%',
#  'awards_won?',
#  'avg_training_score',
#  'is_promoted']

# %%
awards = df.groupby('awards_won?')['is_promoted'].mean()*100

# %%
awards.reset_index()
# Out:
#    awards_won?  is_promoted
# 0            0     7.674922
# 1            1    44.015748

# %%
kpi_met = df['KPIs_met >80%'].mean()*100

# %%
t
# Out:
# ['employee_id',
#  'department',
#  'region',
#  'education',
#  'gender',
#  'recruitment_channel',
#  'no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'KPIs_met >80%',
#  'awards_won?',
#  'avg_training_score',
#  'is_promoted']

# %%
kpi_met
# Out:
# 35.19741643555685

# %%
won_awards = df.groupby('department')['awards_won?'].sum()

# %%
won_awards.reset_index()
# Out:
#           department  awards_won?
# 0          Analytics          130
# 1            Finance           70
# 2                 HR           45
# 3              Legal           25
# 4         Operations          262
# 5        Procurement          171
# 6                R&D           21
# 7  Sales & Marketing          361
# 8         Technology          185

# %%
won = df.groupby('department')['awards_won?'].sum()

# %%
won.reset_index()
# Out:
#           department  awards_won?
# 0          Analytics          130
# 1            Finance           70
# 2                 HR           45
# 3              Legal           25
# 4         Operations          262
# 5        Procurement          171
# 6                R&D           21
# 7  Sales & Marketing          361
# 8         Technology          185

# %%
t
# Out:
# ['employee_id',
#  'department',
#  'region',
#  'education',
#  'gender',
#  'recruitment_channel',
#  'no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'KPIs_met >80%',
#  'awards_won?',
#  'avg_training_score',
#  'is_promoted']

# %%
met_kpi = df.groupby('KPIs_met >80%')['is_promoted'].mean()*100

# %%
filter_data = met_kpi.reset_index()
filter_data.columns = ["KPIs_met >80%", "Promotion_Rate"]
filter_data[filter_data["KPIs_met >80%"]==1] 
#output is wrong
# Out:
#    KPIs_met >80%  Promotion_Rate
# 1              1        16.90944

# %%
filter_data = df.groupby("KPIs_met >80%")["is_promoted"].mean() * 100
filter_data_df = filter_data.reset_index()
filter_data_df.columns = ["KPIs_met >80%", "Promotion_Rate"]
filter_data_df[filter_data_df["KPIs_met >80%"]==1]
# Out:
#    KPIs_met >80%  Promotion_Rate
# 1              1        16.90944

# %%
filter_data_df
# Out:
#    KPIs_met >80%  Promotion_Rate
# 0              0        3.958668
# 1              1       16.909440

# %%
t
# Out:
# ['employee_id',
#  'department',
#  'region',
#  'education',
#  'gender',
#  'recruitment_channel',
#  'no_of_trainings',
#  'age',
#  'previous_year_rating',
#  'length_of_service',
#  'KPIs_met >80%',
#  'awards_won?',
#  'avg_training_score',
#  'is_promoted']

# %%
link = df.groupby('awards_won?')['KPIs_met >80%'].mean()*100

# %%
link.reset_index()
# Out:
#    awards_won?  KPIs_met >80%
# 0            0      34.483918
# 1            1      65.275591

# %%
region = df['region'].value_counts()

# %%
filter = region.reset_index()
filter.columns=['Region','Region_counts']
result = filter.loc[filter['Region_counts'].idxmax()]

# %%
result
# Out:
# Region           region_2
# Region_counts       12343
# Name: 0, dtype: object
